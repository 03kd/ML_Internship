# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('week2.csv')

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df
# Out:
#        Symbol Series        Date  Prev Close  Open Price  High Price  \
# 0    AXISBANK     EQ  2017-05-16      500.10      502.10      504.50
# 1    AXISBANK     EQ  2017-05-17      501.50      501.35      506.75
# 2    AXISBANK     EQ  2017-05-18      502.80      498.00      499.10
# 3    AXISBANK     EQ  2017-05-19      492.00      495.75      503.85
# 4    AXISBANK     EQ  2017-05-22      501.70      504.00      507.45
# ..        ...    ...         ...         ...         ...         ...
# 488  AXISBANK     EQ  2019-05-07      747.45      751.85      755.50
# 489  AXISBANK     EQ  2019-05-08      741.85      741.90      744.75
# 490  AXISBANK     EQ  2019-05-09      735.50      733.90      740.50
# 491  AXISBANK     EQ  2019-05-10      731.00      734.40      738.50
# 492  AXISBANK     EQ  2019-05-13      735.05      734.00      742.85
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# ...

# %%
df.dtypes
# Out:
# Symbol                     object
# Series                     object
# Date                       object
# Prev Close                float64
# Open Price                float64
# High Price                float64
# Low Price                 float64
# Last Price                float64
# Close Price               float64
# Average Price             float64
# Total Traded Quantity       int64
# Turnover                  float64
# No. of Trades               int64
# Deliverable Qty             int64
# % Dly Qt to Traded Qty    float64
# Day_Perc_Change           float64
# Trend                      object
# dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# Symbol                            object
# Series                            object
# Date                      datetime64[ns]
# Prev Close                       float64
# Open Price                       float64
# High Price                       float64
# Low Price                        float64
# Last Price                       float64
# Close Price                      float64
# Average Price                    float64
# Total Traded Quantity              int64
# Turnover                         float64
# No. of Trades                      int64
# Deliverable Qty                    int64
# % Dly Qt to Traded Qty           float64
# Day_Perc_Change                  float64
# Trend                             object
# dtype: object

# %%
df.set_index('Date', inplace=True)

# %%
df
# Out:
#               Symbol Series  Prev Close  Open Price  High Price  Low Price  \
# Date
# 2017-05-16  AXISBANK     EQ      500.10      502.10      504.50     493.50
# 2017-05-17  AXISBANK     EQ      501.50      501.35      506.75     498.50
# 2017-05-18  AXISBANK     EQ      502.80      498.00      499.10     490.25
# 2017-05-19  AXISBANK     EQ      492.00      495.75      503.85     494.20
# 2017-05-22  AXISBANK     EQ      501.70      504.00      507.45     499.50
# ...              ...    ...         ...         ...         ...        ...
# 2019-05-07  AXISBANK     EQ      747.45      751.85      755.50     740.00
# 2019-05-08  AXISBANK     EQ      741.85      741.90      744.75     733.35
# 2019-05-09  AXISBANK     EQ      735.50      733.90      740.50     729.40
# 2019-05-10  AXISBANK     EQ      731.00      734.40      738.50     729.50
# 2019-05-13  AXISBANK     EQ      735.05      734.00      742.85     730.00
#
# ...

# %%
sns.set_style("darkgrid")
plt.xticks(rotation=50)
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['figure.figsize']= 18,8
plt.plot(df['Close Price'])
plt.gca().set(xlabel='Dates', ylabel ='Closing Price', title ="Trend of Stock Movement")
# Out:
# [Text(0, 0.5, 'Closing Price'),
#  Text(0.5, 0, 'Dates'),
#  Text(0.5, 1.0, 'Trend of Stock Movement')]

# %%
df.head()
# Out:
#               Symbol Series  Prev Close  Open Price  High Price  Low Price  \
# Date
# 2017-05-16  AXISBANK     EQ       500.1      502.10      504.50     493.50
# 2017-05-17  AXISBANK     EQ       501.5      501.35      506.75     498.50
# 2017-05-18  AXISBANK     EQ       502.8      498.00      499.10     490.25
# 2017-05-19  AXISBANK     EQ       492.0      495.75      503.85     494.20
# 2017-05-22  AXISBANK     EQ       501.7      504.00      507.45     499.50
#
#             Last Price  Close Price  Average Price  Total Traded Quantity  \
# Date
# 2017-05-16      502.05        501.5         499.85                8610492
# 2017-05-17      502.00        502.8         502.88                6443135
# 2017-05-18      492.85        492.0         494.96                9227022
# 2017-05-19      501.90        501.7         499.10                7611430
# 2017-05-22      502.00        502.3         503.00                4970982
#
# ...

# %%
x = df.Day_Perc_Change.values

# %%
plt.stem(df.index,df['Day_Perc_Change'],use_line_collection =True)
plt.xlabel('Date')
plt.xticks(rotation=50)
plt.ylabel('% Change in Closing Price')
plt.show()

# %% [markdown]
# ### Q-3

# %%
x= df.index.values
y = df['Total Traded Quantity'].values

# %%
sns.lineplot(x,y)
plt.xticks(rotation=50)
plt.rcParams['xtick.labelsize'] = 10
plt.gca().set(xlabel='Date', ylabel='Quantity Traded', title="Volume Trend")
# Out:
# [Text(0, 0.5, 'Quantity Traded'),
#  Text(0.5, 0, 'Date'),
#  Text(0.5, 1.0, 'Volume Trend')]

# %% [markdown]
# ### Pie Chart

# %%
df1 = df.groupby(['Trend'], as_index=False)

# %%
df2 = df1.count()
li = []
labels = df2['Trend']
colors = ['#ff1a1a','#33cccc','#cc66ff','#e6e600','#00cc00','#666633','#9900ff','#ccccff','#660033']
for i in df2['Symbol']:
    x = (i / df2['Symbol'].sum())
    li.append(x*100)

plt.figure(figsize=(10,8))
plt.pie(li,labels = labels,autopct ="%1.1f%%",colors = colors,startangle = 20,
        explode = (0.,0.,0.1,0.1,0,0,0,0.1,0.1),pctdistance =0.7, labeldistance = 1.1,radius =1.5)
plt.tight_layout()
plt.show()

# %%
df3 = df1.median()

sns.barplot(x="Trend", y="Total Traded Quantity", data =df3, color='blue')
plt.title("Median")
# Out:
# Text(0.5, 1.0, 'Median')

# %%
df4= df1.mean()
sns.barplot(x='Trend', y='Total Traded Quantity', data=df4, color='red')
plt.title('Median')
# Out:
# Text(0.5, 1.0, 'Median')

# %% [markdown]
# ### Q-5

# %%
x = df['Day_Perc_Change'].values
plt.hist(x, bins=60)
plt.xlabel("% change")
plt.ylabel("Frequency")
plt.title("Daily Return Distribution")
plt.show()

# %%
ds1 = pd.read_csv("stock_data/BAJFINANCE.csv") #BAJFINANCE.CSV
ds2 = pd.read_csv("stock_data/IDBI.csv")    #IDBI.CSV
ds3 = pd.read_csv("stock_data/IDFC.csv")   #IDFC.CSV
ds4 = pd.read_csv("stock_data/PNB.csv")     #PNB.CSV
ds5 = pd.read_csv("stock_data/RBLBANK.csv") #RBLBANK.CSV

# %%
for stock in [ds1,ds2,ds3,ds4,ds5]:
    stock = stock[stock.Series =='EQ']

# %%
close_dict = {'bajfinance_cp':ds1['Close Price'].values[:494],
            'idbi_cp':ds2['Close Price'].values[:494],
            'idfc_cp':ds3['Close Price'].values[:494],
            'pnb_cp':ds4['Close Price'].values[:494],
            'rblbank':ds5['Close Price'].values[:494]}

# %%
close_dfs = pd.DataFrame(close_dict)
close_dfs.head()
# Out:
#    bajfinance_cp  idbi_cp  idfc_cp  pnb_cp  rblbank
# 0        1332.95    75.05    63.70  166.80   563.90
# 1        1347.75    76.65    64.25  174.15   562.60
# 2        1324.80    75.95    63.35  165.05   564.25
# 3        1314.55    69.95    61.50  158.50   552.15
# 4        1289.15    68.75    61.15  155.20   555.45

# %%
pct_close_dfs = close_dfs.pct_change()*100
pct_close_dfs.dropna(axis =0, inplace =True)
pct_close_dfs.reset_index(drop=True, inplace =True)

# %%
pct_close_dfs.head()
# Out:
#    bajfinance_cp   idbi_cp   idfc_cp    pnb_cp   rblbank
# 0       1.110319  2.131912  0.863422  4.406475 -0.230537
# 1      -1.702838 -0.913242 -1.400778 -5.225380  0.293281
# 2      -0.773702 -7.899934 -2.920284 -3.968494 -2.144440
# 3      -1.932220 -1.715511 -0.569106 -2.082019  0.597664
# 4      -3.645813 -3.709091 -1.553557 -2.738402 -1.908363

# %%
sns.set_style('darkgrid')
g= sns.PairGrid(pct_close_dfs)
g.map_diag(plt.hist, color='red')
g.map_offdiag(plt.scatter)

# %% [markdown]
# ### Q-7

# %%
rolling_df = pct_close_dfs.rolling(7).mean()
df_rolled = rolling_df.idbi_cp

# %%
df_rolled = df_rolled[6:]
df_rolled.head(5)
# Out:
# 6    -2.868408
# 7    -3.009033
# 8    -2.658611
# 9    -2.100110
# 10   -1.712536
# Name: idbi_cp, dtype: float64

# %%
df_standard = pct_close_dfs.idbi_cp.rolling(7).std()[6:]
df_standard.head(5)
# Out:
# 6     3.338196
# 7     3.105037
# 8     3.494917
# 9     2.750923
# 10    2.994475
# Name: idbi_cp, dtype: float64

# %%
volatile_dataframe = pd.DataFrame({
    'Date':df.index.values[6:],
    'Rollling_avg':df_rolled,
    'Standard_Dev':df_standard
})

# %%
volatile_dataframe.head()
# Out:
#          Date  Rollling_avg  Standard_Dev
# 6  2017-05-24     -2.868408      3.338196
# 7  2017-05-25     -3.009033      3.105037
# 8  2017-05-26     -2.658611      3.494917
# 9  2017-05-29     -2.100110      2.750923
# 10 2017-05-30     -1.712536      2.994475

# %%
x = volatile_dataframe.Date.values
y = volatile_dataframe.Standard_Dev
sns.lineplot(x,y)
plt.gca().set(xlabel ='Date', ylabel='Standard Deviation', title ='Volatile Trend')
# Out:
# [Text(0, 0.5, 'Standard Deviation'),
#  Text(0.5, 0, 'Date'),
#  Text(0.5, 1.0, 'Volatile Trend')]

# %% [markdown]
# ### Q-8

# %%
df_nifty = pd.read_csv('Nifty50.csv')
df_nifty.head(10)
# Out:
#           Date     Open     High      Low    Close  Shares Traded  \
# 0  15-May-2017  9433.55  9449.25  9423.10  9445.40      145163953
# 1  16-May-2017  9461.00  9517.20  9456.35  9512.25      171709433
# 2  17-May-2017  9517.60  9532.60  9486.10  9525.75      211856040
# 3  18-May-2017  9453.20  9489.10  9418.10  9429.45      199340647
# 4  19-May-2017  9469.90  9505.75  9390.75  9427.90      259861396
# 5  22-May-2017  9480.25  9498.65  9427.90  9438.25      202874757
# 6  23-May-2017  9445.05  9448.05  9370.00  9386.15      231345629
# 7  24-May-2017  9410.90  9431.90  9341.65  9360.55      218265181
# 8  25-May-2017  9384.05  9523.30  9379.20  9509.75      298147347
# 9  26-May-2017  9507.75  9604.90  9495.40  9595.10      225647631
#
#    Turnover (Rs. Cr)
# 0            7790.97
# 1            9209.89
# 2           10726.23
# 3           10782.46
# 4           11544.77
# 5            9432.97
# 6           11553.27
# 7           11045.95
# 8           16964.26
# ...

# %%
df_nifty['perc_change'] = df_nifty.Close.pct_change()*100

# %%
df_nifty['rolling'] = df_nifty.Close.rolling(7).mean()

# %%
df_nifty['std_dev'] = df_nifty.perc_change.rolling(7).std()

# %%
df_nifty['Date'] =pd.to_datetime(df_nifty.Date)
df_nifty[:10]
# Out:
#         Date     Open     High      Low    Close  Shares Traded  \
# 0 2017-05-15  9433.55  9449.25  9423.10  9445.40      145163953
# 1 2017-05-16  9461.00  9517.20  9456.35  9512.25      171709433
# 2 2017-05-17  9517.60  9532.60  9486.10  9525.75      211856040
# 3 2017-05-18  9453.20  9489.10  9418.10  9429.45      199340647
# 4 2017-05-19  9469.90  9505.75  9390.75  9427.90      259861396
# 5 2017-05-22  9480.25  9498.65  9427.90  9438.25      202874757
# 6 2017-05-23  9445.05  9448.05  9370.00  9386.15      231345629
# 7 2017-05-24  9410.90  9431.90  9341.65  9360.55      218265181
# 8 2017-05-25  9384.05  9523.30  9379.20  9509.75      298147347
# 9 2017-05-26  9507.75  9604.90  9495.40  9595.10      225647631
#
#    Turnover (Rs. Cr)  perc_change      rolling   std_dev
# 0            7790.97          NaN          NaN       NaN
# 1            9209.89     0.707752          NaN       NaN
# 2           10726.23     0.141922          NaN       NaN
# ...

# %%
x = volatile_dataframe.Date.values
y = volatile_dataframe.Standard_Dev
sns.lineplot(x, y,color ='red', label='IDBI')
sns.lineplot(data =df_nifty, x=df_nifty.Date.values[6:], y = df_nifty.std_dev[6:], color ='Green', label='Nifty')
plt.gca().set(xlabel = 'Date', ylabel='Standard Deviation', title='Trend of Volatility')
# Out:
# [Text(0, 0.5, 'Standard Deviation'),
#  Text(0.5, 0, 'Date'),
#  Text(0.5, 1.0, 'Trend of Volatility')]

# %% [markdown]
# ### Q-9

# %%
sma_21 = pd.DataFrame({'Date':df[20:].index.values, 'SMA':df['Close Price'].rolling(21).mean()[20:]})

# %%
sma_34 = pd.DataFrame({'Date':df[34:].index.values, 'SMA':df['Close Price'].rolling(34).mean()[34:]})

# %%
sns.lineplot(data =df, x =df.index, y ='Average Price', color ='blue', label='Average Price')
sns.lineplot(data =sma_21, x ='Date', y ='SMA', color='red', label='SMA_21')
sns.lineplot(data =sma_34, x='Date', y='SMA', color ='green', label ='SMA_34')
plt.gca().set(xlabel ='Date', ylabel='Simple Moving Averages', title ='Simple Moving Average Trend')
# Out:
# [Text(0, 0.5, 'Simple Moving Averages'),
#  Text(0.5, 0, 'Date'),
#  Text(0.5, 1.0, 'Simple Moving Average Trend')]

# %% [markdown]
# ### Q-10

# %%
df.head()
# Out:
#               Symbol Series  Prev Close  Open Price  High Price  Low Price  \
# Date
# 2017-05-16  AXISBANK     EQ       500.1      502.10      504.50     493.50
# 2017-05-17  AXISBANK     EQ       501.5      501.35      506.75     498.50
# 2017-05-18  AXISBANK     EQ       502.8      498.00      499.10     490.25
# 2017-05-19  AXISBANK     EQ       492.0      495.75      503.85     494.20
# 2017-05-22  AXISBANK     EQ       501.7      504.00      507.45     499.50
#
#             Last Price  Close Price  Average Price  Total Traded Quantity  \
# Date
# 2017-05-16      502.05        501.5         499.85                8610492
# 2017-05-17      502.00        502.8         502.88                6443135
# 2017-05-18      492.85        492.0         494.96                9227022
# 2017-05-19      501.90        501.7         499.10                7611430
# 2017-05-22      502.00        502.3         503.00                4970982
#
# ...

# %%
roll_14 = df['Close Price'].rolling(14).mean()[13:]
std_14  = df['Close Price'].rolling(14).std()[13:]

# %%
upper_band = roll_14 + 2*std_14
lower_band = roll_14 - 2*std_14

# %%
avg_stock_price = df['Average Price'][13:]

# %%
bollinger_df = pd.DataFrame({'Date':avg_stock_price.index.values,
                            'Rolling_14':roll_14, 
                            'Std_14':std_14,
                             'Average Price':avg_stock_price,
                            'Upper_band':upper_band,
                            'Lower_band':lower_band})

# %%
bollinger_df.head()
# Out:
#                  Date  Rolling_14    Std_14  Average Price  Upper_band  \
# Date
# 2017-06-02 2017-06-02  505.153571  6.241994         509.46  517.637559
# 2017-06-05 2017-06-05  506.021429  6.532808         513.15  519.087045
# 2017-06-06 2017-06-06  506.550000  6.551453         509.31  519.652906
# 2017-06-07 2017-06-07  508.135714  5.332031         511.95  518.799775
# 2017-06-08 2017-06-08  509.139286  5.349737         517.07  519.838759
#
#             Lower_band
# Date
# 2017-06-02  492.669584
# 2017-06-05  492.955812
# 2017-06-06  493.447094
# 2017-06-07  497.471653
# 2017-06-08  498.439812

# %%
sns.lineplot(data =bollinger_df, x ='Date', y = 'Average Price', label ='Average Price', color='DarkGreen')
sns.lineplot(data =bollinger_df, x ='Date', y = 'Rolling_14', label ='Rolling 14', color='Maroon')
sns.lineplot(data = bollinger_df, x ='Date', y = 'Upper_band', label ='Upper Band', color='Black')
sns.lineplot(data = bollinger_df, x ='Date', y = 'Lower_band', label ='Lower Band', color='DodgerBlue')
plt.gca().set(xlabel ='Date', ylabel ='Stock Price', title ='Bollinger Bands')
# Out:
# [Text(0, 0.5, 'Stock Price'),
#  Text(0.5, 0, 'Date'),
#  Text(0.5, 1.0, 'Bollinger Bands')]

# %% [markdown]
# The bands tend to be quite accurate in making a prediction of volatility. It can be clearly seen that whenever the upper and lower bands squeeze or narrow down, there is relatively a situation of low volatility but when these bands move apart the change in stock price is very volatile as evident from the plot.
# Also, a squeeze is followed by broadening out of the bands and vice versa which can give a hint about what trend the stock price is about to follow in the future.

# %%
df['Rolling_14'] = df['Close Price'].rolling(14).mean()
df['Std_14'] = df['Close Price'].rolling(14).std()
df['Upper_band'] = roll_14 + 2*std_14
df['Lower_band'] = roll_14 - 2*std_14

# %%
df.to_csv('week3.csv')
